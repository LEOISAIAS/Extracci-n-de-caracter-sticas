# %% [markdown]
# <a href="https://colab.research.google.com/github/LEOISAIAS/Extracci-n-de-caracter-sticas/blob/main/Extracci%C3%B3n_de_Caracter%C3%ADsticas_A01275327.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extracción de características**
#
#
# ## Leonardo Isaías Guevara Pioquinto
#
# ## A01275327

# %%
#Instalamos librería para análisis de variables categóricas
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: funpymodeling in /usr/local/lib/python3.10/dist-packages (0.1.7)
# Requirement already satisfied: matplotlib<4.0.0,>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (3.7.1)
# Requirement already satisfied: numpy<2.0.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (1.5.3)
# Requirement already satisfied: seaborn<0.11.0,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (0.10.1)
# Requirement already satisfied: sklearn<0.1,>=0.0 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (0.0.post4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.5->funpymodeling) (2022.7.1)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from seaborn<0.11.0,>=0.10.1->funpymodeling) (1.10.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.16.0)

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimo los primeros 30 registro del dataframe
df.head(30)
# Out:
#                               _record_id             _title  \
# 0   dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1   c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2   5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3   6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4   6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
# 5   2ab862d8-1449-42fe-9de0-63f0fa86e41c  November 12, 2022
# 6   eac16b89-1988-491f-a827-60481298aa35  November 12, 2022
# 7   719cdad7-cf49-4c64-9f1d-004279b71da0  November 12, 2022
# 8   b7494ae1-8154-4538-afd2-f9362d561ed1  November 12, 2022
# 9   684fc35a-25b7-47b4-be58-bbc8c5bab3fb  November 12, 2022
# 10  74688e80-21b7-4356-9362-6fb2ba1e4f30  November 12, 2022
# 11  e8009ddb-9e2e-44aa-8721-21fbc2fb157e  November 12, 2022
# 12  a608b152-7ed5-4e56-a5ab-589867ab0b65  November 12, 2022
# 13  f740f232-fc37-4ea5-a5f2-87c1f2ae1951  November 12, 2022
# 14  5e8464b9-0b58-4520-a4fc-9c17a8b30500  November 12, 2022
# 15  609385f7-57c8-4210-b927-8b2a9c76ea2c   November 9, 2022
# 16  461b41ec-1b3b-4d20-9414-8fb66a6e051b   November 9, 2022
# 17  6bb75354-101c-48b1-9c82-76e40f90159c   November 9, 2022
# 18  77339a78-1542-4445-9403-4344786da162   November 9, 2022
# 19  ac115611-d079-46dc-bdb6-5095a71fde01   November 9, 2022
# 20  9fc2adeb-ac67-46ef-b4db-8f4afb139ecc  November 11, 2022
# 21  054d2e34-6343-451f-8d71-d87c1599a614   November 9, 2022
# 22  b062ce9a-496c-47d1-a193-d8204cc8d968   November 9, 2022
# 23  bc2a99bc-7c06-4746-85c9-9e53823d9183   November 9, 2022
# 24  9e202c7e-1c78-4a72-bb84-110a11f16f1a   November 9, 2022
# 25  dffe1660-c71a-40a5-9578-1335e9b18536   November 9, 2022
# 26  388f22fd-1484-4443-96b9-d6b7bc79f3b8   November 9, 2022
# 27  22ab11ce-fc2c-4031-9f23-74e21486b0f6   November 9, 2022
# 28  99f132d3-41dc-47b7-9466-7db694dcd507   November 9, 2022
# 29  721a3a26-9865-49f3-9974-dd002febe563   November 9, 2022
#
#          _server_updated_at                        _updated_by  \
# 0   2022-11-12 22:15:10 UTC               Salomon Abdala Perez
# 1   2022-11-12 22:15:09 UTC               Salomon Abdala Perez
# 2   2022-11-12 22:15:09 UTC               Salomon Abdala Perez
# 3   2022-11-12 22:15:09 UTC               Salomon Abdala Perez
# 4   2022-11-12 22:15:08 UTC               Salomon Abdala Perez
# 5   2022-11-12 22:15:07 UTC               Salomon Abdala Perez
# 6   2022-11-12 22:15:06 UTC               Salomon Abdala Perez
# 7   2022-11-12 22:15:06 UTC               Salomon Abdala Perez
# 8   2022-11-12 22:15:05 UTC               Salomon Abdala Perez
# 9   2022-11-12 22:15:05 UTC               Salomon Abdala Perez
# 10  2022-11-12 21:43:07 UTC  Ángel Francisco Altamirano Campos
# 11  2022-11-12 21:43:06 UTC  Ángel Francisco Altamirano Campos
# 12  2022-11-12 21:43:06 UTC  Ángel Francisco Altamirano Campos
# 13  2022-11-12 21:43:05 UTC  Ángel Francisco Altamirano Campos
# 14  2022-11-12 21:43:05 UTC  Ángel Francisco Altamirano Campos
# 15  2022-11-12 21:43:04 UTC  Ángel Francisco Altamirano Campos
# 16  2022-11-12 21:43:04 UTC  Ángel Francisco Altamirano Campos
# 17  2022-11-12 21:43:03 UTC  Ángel Francisco Altamirano Campos
# 18  2022-11-12 21:43:03 UTC  Ángel Francisco Altamirano Campos
# 19  2022-11-12 21:43:02 UTC  Ángel Francisco Altamirano Campos
# 20  2022-11-12 02:03:45 UTC                     Sandra Carreón
# 21  2022-11-11 23:12:55 UTC                      Hiram Jiménez
# 22  2022-11-11 23:12:54 UTC                      Hiram Jiménez
# 23  2022-11-11 23:12:54 UTC                      Hiram Jiménez
# 24  2022-11-11 23:12:53 UTC                      Hiram Jiménez
# 25  2022-11-11 23:12:53 UTC                      Hiram Jiménez
# 26  2022-11-11 23:12:52 UTC                      Hiram Jiménez
# 27  2022-11-11 22:11:34 UTC                    Harry Hernández
# 28  2022-11-11 22:11:34 UTC                    Harry Hernández
# 29  2022-11-11 22:11:34 UTC                    Harry Hernández
#
#                                         _geometry  _latitude  _longitude  \
# 0    SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1   SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2     SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# 3   SRID=4326;POINT(-98.2331576513 19.0592929035)  19.059293  -98.233158
# 4   SRID=4326;POINT(-98.2338639604 19.0595846029)  19.059585  -98.233864
# 5   SRID=4326;POINT(-98.2340100497 19.0595598862)  19.059560  -98.234010
# 6    SRID=4326;POINT(-98.233027074 19.0590374022)  19.059037  -98.233027
# 7   SRID=4326;POINT(-98.2298178552 19.0607069876)  19.060707  -98.229818
# 8   SRID=4326;POINT(-98.2252770749 19.0594737148)  19.059474  -98.225277
# 9   SRID=4326;POINT(-98.2242125705 19.0588832074)  19.058883  -98.224213
# 10        SRID=4326;POINT(-98.2609888 19.0203363)  19.020336  -98.260989
# 11        SRID=4326;POINT(-98.2611121 19.0203285)  19.020329  -98.261112
# 12        SRID=4326;POINT(-98.2609604 19.0204215)  19.020422  -98.260960
# 13         SRID=4326;POINT(-98.2608668 19.020395)  19.020395  -98.260867
# 14        SRID=4326;POINT(-98.2608038 19.0205671)  19.020567  -98.260804
# 15        SRID=4326;POINT(-98.2607229 19.0207622)  19.020762  -98.260723
# 16        SRID=4326;POINT(-98.2606615 19.0208774)  19.020877  -98.260661
# 17         SRID=4326;POINT(-98.260586 19.0210881)  19.021088  -98.260586
# 18        SRID=4326;POINT(-98.2603816 19.0213946)  19.021395  -98.260382
# 19         SRID=4326;POINT(-98.2602834 19.021461)  19.021461  -98.260283
# 20  SRID=4326;POINT(-98.1944422847 19.0449409657)  19.044941  -98.194442
# 21        SRID=4326;POINT(-98.3127512 19.0655137)  19.065514  -98.312751
# 22        SRID=4326;POINT(-98.3109706 19.0656707)  19.065671  -98.310971
# 23        SRID=4326;POINT(-98.3097669 19.0638125)  19.063813  -98.309767
# 24        SRID=4326;POINT(-98.3109695 19.0614541)  19.061454  -98.310969
# 25        SRID=4326;POINT(-98.3111919 19.0612258)  19.061226  -98.311192
# 26        SRID=4326;POINT(-98.3112764 19.0608665)  19.060866  -98.311276
# 27  SRID=4326;POINT(-98.3067292227 19.0618356185)  19.061836  -98.306729
# 28  SRID=4326;POINT(-98.3060609457 19.0605136519)  19.060514  -98.306061
# 29   SRID=4326;POINT(-98.306741458 19.0597415325)  19.059742  -98.306741
#
#                            228_store_name 229_store_picture  \
# 0                     Eugene’s Compostura           1 Photo
# 1                  Frutas y verduras Angy           1 Photo
# 2                               Libélula            1 Photo
# 3                             Quality fix           1 Photo
# 4                    Artesanías Los Pinos           1 Photo
# 5                                 La fête           1 Photo
# 6                               Yo reparo           1 Photo
# 7                     Miscenlánea Manolos           1 Photo
# 8                          Mundo Ciclista           1 Photo
# 9                            Copias & Max           1 Photo
# 10  Desechables y materias primas Alondra           1 Photo
# 11                              Internet            1 Photo
# 12                      Ferretería Fénix            1 Photo
# 13                               Polleria           1 Photo
# 14                      Tortas planchadas           1 Photo
# 15                              Dulceria            1 Photo
# 16                    Acuario y mascotas            1 Photo
# 17                             Tortas cue           1 Photo
# 18                           Tacos Robert           1 Photo
# 19                      Productos Aldhemi           1 Photo
# 20                                  Mony            1 Photo
# 21                          dulce detalle           1 Photo
# 22                              Jerusalen           1 Photo
# 23             Salchichonerias San Pedro            1 Photo
# 24                        Abarrotes Diana           1 Photo
# 25                        Abarrotes jaime           1 Photo
# 26                  Abarrotes el solecito           1 Photo
# 27                  Miscelánea el zócalo            1 Photo
# 28                           La pirámide            1 Photo
# 29                   Miscelánea teocalli            1 Photo
#
#                   232_type_of_store  ... 261_technology_organization  \
# 0                            Tailor  ...                         NaN
# 1    Grocery store (aka. nanostore)  ...                         NaN
# 2    Grocery store (aka. nanostore)  ...                         NaN
# 3    Grocery store (aka. nanostore)  ...                         NaN
# 4    Grocery store (aka. nanostore)  ...                         NaN
# 5                         Cafeteria  ...                         NaN
# 6                  Technology Store  ...                         NaN
# 7    Grocery store (aka. nanostore)  ...                         NaN
# 8                    Retailer store  ...                         NaN
# 9    Grocery store (aka. nanostore)  ...                         NaN
# 10   Grocery store (aka. nanostore)  ...                  De acuerdo
# 11                        internet   ...                  De acuerdo
# 12                      Ferretería   ...       Totalmente de acuerdo
# 13                     Butcher shop  ...       Totalmente de acuerdo
# 14  Micro-restaurant (aka. fondita)  ...                  De acuerdo
# 15                        Dulceria   ...               En desacuerdo
# 16                        Pet store  ...       Totalmente de acuerdo
# 17  Micro-restaurant (aka. fondita)  ...    Totalmente en desacuerdo
# 18  Micro-restaurant (aka. fondita)  ...                  De acuerdo
# 19                    Cosmetiquera   ...                  De acuerdo
# 20                   Dairy products  ...                  De acuerdo
# 21   Grocery store (aka. nanostore)  ...                         NaN
# 22   Grocery store (aka. nanostore)  ...                         NaN
# 23                     Butcher shop  ...                         NaN
# 24   Grocery store (aka. nanostore)  ...                         NaN
# 25   Grocery store (aka. nanostore)  ...                         NaN
# 26   Grocery store (aka. nanostore)  ...                         NaN
# 27   Grocery store (aka. nanostore)  ...                         NaN
# 28   Grocery store (aka. nanostore)  ...                         NaN
# 29   Grocery store (aka. nanostore)  ...                         NaN
#
#     262_technology_serve_customers     263_technology_secure_sales  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# 5                              NaN                             NaN
# 6                       De acuerdo  Ni de acuerdo ni en desacuerdo
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                   En desacuerdo                      De acuerdo
# 11                      De acuerdo                      De acuerdo
# 12                      De acuerdo                      De acuerdo
# 13                      De acuerdo                   En desacuerdo
# 14                      De acuerdo                      De acuerdo
# 15        Totalmente en desacuerdo        Totalmente en desacuerdo
# 16                      De acuerdo           Totalmente de acuerdo
# 17        Totalmente en desacuerdo        Totalmente en desacuerdo
# 18                      De acuerdo                      De acuerdo
# 19  Ni de acuerdo ni en desacuerdo                      De acuerdo
# 20                      De acuerdo                   En desacuerdo
# 21                             NaN                             NaN
# 22                             NaN                             NaN
# 23                             NaN                             NaN
# 24                             NaN                             NaN
# 25                             NaN                             NaN
# 26                             NaN                             NaN
# 27                             NaN                             NaN
# 28                             NaN                             NaN
# 29                             NaN                             NaN
#
#        264_technology_budget  267_technology_investment_customer_preferences  \
# 0                        NaN                                             NaN
# 1                        NaN                                             NaN
# 2                        NaN                                             NaN
# 3                        NaN                                             NaN
# 4                        NaN                                             NaN
# 5                        NaN                                             NaN
# 6              En desacuerdo                                   En desacuerdo
# 7                        NaN                                             NaN
# 8                        NaN                                             NaN
# 9                        NaN                                             NaN
# 10  Totalmente en desacuerdo                           Totalmente de acuerdo
# 11                De acuerdo                                      De acuerdo
# 12  Totalmente en desacuerdo                           Totalmente de acuerdo
# 13                De acuerdo                           Totalmente de acuerdo
# 14                De acuerdo                                      De acuerdo
# 15                De acuerdo                           Totalmente de acuerdo
# 16     Totalmente de acuerdo                           Totalmente de acuerdo
# 17                De acuerdo                                      De acuerdo
# 18                De acuerdo                                      De acuerdo
# 19                       NaN                                      De acuerdo
# 20  Totalmente en desacuerdo                                      De acuerdo
# 21                       NaN                                             NaN
# 22                       NaN                                             NaN
# 23                       NaN                                             NaN
# 24                       NaN                                             NaN
# 25                       NaN                                             NaN
# 26                       NaN                                             NaN
# 27                       NaN                                             NaN
# 28                       NaN                                             NaN
# 29                       NaN                                             NaN
#
#    234_willingness_participate_workshop  318_shopkeeper_name  \
# 0                                    no                  NaN
# 1                                    no                  NaN
# 2                                    no                  NaN
# 3                                    no                  NaN
# 4                                    no                  NaN
# 5                                    no                  NaN
# 6                                    no                  NaN
# 7                                   yes             Fernanda
# 8                                   yes                Jesús
# 9                                   yes                Rocio
# 10                                   no                  NaN
# 11                                  yes              Victor
# 12                                  yes           Alejandra
# 13                                  yes              Misael
# 14                                  NaN                  NaN
# 15                                  yes              Andrea
# 16                                  yes        Misael Gómez
# 17                                  yes               Jesus
# 18                                   no                  NaN
# 19                                  yes    Andrea Monserrat
# 20                                   no                  NaN
# 21                                  NaN                  NaN
# 22                                  NaN                  NaN
# 23                                  NaN                  NaN
# 24                                  NaN                  NaN
# 25                                  yes                Jaime
# 26                                  NaN                  NaN
# 27                                  NaN                  NaN
# 28                                  NaN                  NaN
# 29                                  NaN                  NaN
#
#    319_shopkeepers_last_name  236_whatsapp                       235_email
# 0                        NaN           NaN                             NaN
# 1                        NaN           NaN                             NaN
# 2                        NaN           NaN                             NaN
# 3                        NaN           NaN                             NaN
# 4                        NaN           NaN                             NaN
# 5                        NaN           NaN                             NaN
# 6                        NaN           NaN                             NaN
# 7                   Escobedo           NaN  fer.escobedo.meneses@gmail.com
# 8                      Lares           NaN   mundociclistapuebla@gmail.com
# 9                    Salazar  2.224524e+09                             NaN
# 10                       NaN           NaN                             NaN
# 11               Cortes Mayo  2.213335e+09      internetorionsur@gmail.com
# 12                  Vasquez   2.213899e+09                             NaN
# 13                  Castelan  2.212182e+09                             NaN
# 14                       NaN           NaN                             NaN
# 15                   Manzano  2.225417e+09                             NaN
# 16                    Pintle  2.223839e+09                             NaN
# 17                    Aguila  2.225987e+09                             NaN
# 18                       NaN           NaN                             NaN
# 19            García Cardozo  4.641174e+09                             NaN
# 20                       NaN           NaN                             NaN
# 21                       NaN           NaN                             NaN
# 22                       NaN           NaN                             NaN
# 23                       NaN           NaN                             NaN
# 24                       NaN           NaN                             NaN
# 25                       NaN           NaN                             NaN
# 26                       NaN           NaN                             NaN
# 27                       NaN           NaN                             NaN
# 28                       NaN           NaN                             NaN
# 29                       NaN           NaN                             NaN
#
# [30 rows x 106 columns]

# %%
# FILTRO DE COLUMNAS SELECCIONADAS 
filtro=df.iloc[ : , [3,9,15,29,32,33,42,53,59,61,71,72,73,85,86,88,89,92,93,94]]  
filtro
# Out:
#               _updated_by                232_type_of_store  \
# 0    Salomon Abdala Perez                           Tailor
# 1    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                    ...                              ...
# 166          Emilio Garza   Grocery store (aka. nanostore)
# 167          Emilio Garza   Grocery store (aka. nanostore)
# 168          Emilio Garza  Micro-restaurant (aka. fondita)
# 169        Francisco Adán  Micro-restaurant (aka. fondita)
# 170          Emilio Garza  Micro-restaurant (aka. fondita)
#
#                                      184_store_devices  \
# 0    POS system (i.e. computer + bar code scanner +...
# 1                       Dataphone (i.e. card payments)
# 2    Dataphone (i.e. card payments),POS system (i.e...
# 3    POS system (i.e. computer + bar code scanner +...
# 4                                           Smartphone
# ..                                                 ...
# 166                    Analog cash register,Smartphone
# 167                    Analog cash register,Smartphone
# 168                                         Smartphone
# 169                               Analog cash register
# 170                                         Smartphone
#
#      103_number_own_fridges 310_burnout  24_burnout  \
# 0                       NaN          no         NaN
# 1                       NaN          no         NaN
# 2                       NaN          no         NaN
# 3                       NaN          no         NaN
# 4                       NaN          no         NaN
# ..                      ...         ...         ...
# 166                     NaN         NaN         NaN
# 167                     NaN         NaN         NaN
# 168                     NaN         NaN         NaN
# 169                     NaN         NaN         NaN
# 170                     NaN         NaN         NaN
#
#      272_card_days_receive_money 193_sales_planning_tools  \
# 0                            NaN   Software especializado
# 1                            NaN                      NaN
# 2                            0.0                      NaN
# 3                            0.0                  Ninguna
# 4                            1.0                      NaN
# ..                           ...                      ...
# 166                          NaN                      NaN
# 167                          NaN                      NaN
# 168                          NaN                      NaN
# 169                          NaN                      NaN
# 170                          NaN                      NaN
#
#      62_frequency_only_services 77_delivery_timeslots  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ..                          ...                   ...
# 166                         NaN                   NaN
# 167                         NaN                   NaN
# 168                         NaN                   NaN
# 169                         NaN                   NaN
# 170                         NaN                   NaN
#
#     44_willingness_inventory_management_suppliers  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 166                                           NaN
# 167                                           NaN
# 168                                           NaN
# 169                                           NaN
# 170                                           NaN
#
#     45_willingness_reorder_suppliers 46_willingness_reorder_suppliers_variety  \
# 0                                NaN                                      NaN
# 1                                NaN                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
# ..                               ...                                      ...
# 166                              NaN                                      NaN
# 167                              NaN                                      NaN
# 168                              NaN                                      NaN
# 169                              NaN                                      NaN
# 170                              NaN                                      NaN
#
#     279_changes_procurement_pandemic 157_frequency_organize_shelves  \
# 0                                NaN                 Semestralmente
# 1                                NaN                            NaN
# 2                                NaN                   Semanalmente
# 3                                NaN                   Semanalmente
# 4                                NaN                   Mensualmente
# ..                               ...                            ...
# 166                              NaN                            NaN
# 167                              NaN                            NaN
# 168                              NaN                            NaN
# 169                              NaN                            NaN
# 170                              NaN                            NaN
#
#                                  161_actions_stockouts  \
# 0    Solicitar tiempo al cliente para conseguir el ...
# 1    Ofrecer un producto sustituto,Solicitar tiempo...
# 2                                      Perder la venta
# 3                        Ofrecer un producto sustituto
# 4    Informar al proveedor,Solicitar tiempo al clie...
# ..                                                 ...
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
#
#     162_inventory_extra_space 250_technology_investment_operations  \
# 0                           0                                  NaN
# 1                         10%                                  NaN
# 2                         10%                                  NaN
# 3                           0                                  NaN
# 4                           0                                  NaN
# ..                        ...                                  ...
# 166                       NaN                                  NaN
# 167                       NaN                                  NaN
# 168                       NaN                                  NaN
# 169                       NaN                                  NaN
# 170                       NaN                                  NaN
#
#     251_technology_investment_customers 254_technology_roadmap
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ..                                  ...                    ...
# 166                                 NaN                    NaN
# 167                                 NaN                    NaN
# 168                                 NaN                    NaN
# 169                                 NaN                    NaN
# 170                                 NaN                    NaN
#
# [171 rows x 20 columns]

# %%
# VALORES NULOS
filtro["_updated_by"] =filtro["_updated_by"].fillna("--")
# Out:
# <ipython-input-46-bfc542a6783c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["_updated_by"] =filtro["_updated_by"].fillna("--")

# %%
#VALORES NULOS
filtro["232_type_of_store"] =filtro["232_type_of_store"].fillna("--")
# Out:
# <ipython-input-47-25dd63ace367>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["232_type_of_store"] =filtro["232_type_of_store"].fillna("--")

# %%
#VALORES NULOS
filtro["184_store_devices"] =filtro["184_store_devices"].fillna("--")
# Out:
# <ipython-input-48-2025a3efafbe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["184_store_devices"] =filtro["184_store_devices"].fillna("--")

# %%
#VALORES NULOS
filtro["103_number_own_fridges"] =filtro["103_number_own_fridges"].fillna("--")
# Out:
# <ipython-input-49-e8cba0d5aa28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["103_number_own_fridges"] =filtro["103_number_own_fridges"].fillna("--")

# %%
#VALORES NULOS
filtro["310_burnout"] =filtro["310_burnout"].fillna("--")
# Out:
# <ipython-input-50-2afc9a49a781>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["310_burnout"] =filtro["310_burnout"].fillna("--")

# %%
#VALORES NULOS
filtro["24_burnout"] =filtro["24_burnout"].fillna("--")
# Out:
# <ipython-input-51-7f555f0c2439>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["24_burnout"] =filtro["24_burnout"].fillna("--")

# %%
#VALORES NULOS
filtro["272_card_days_receive_money"] =filtro["272_card_days_receive_money"].fillna("--")
# Out:
# <ipython-input-52-4bcd0917bee1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["272_card_days_receive_money"] =filtro["272_card_days_receive_money"].fillna("--")

# %%
#VALORES NULOS
filtro["272_card_days_receive_money"] =filtro["272_card_days_receive_money"].fillna("--")
# Out:
# <ipython-input-53-4bcd0917bee1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["272_card_days_receive_money"] =filtro["272_card_days_receive_money"].fillna("--")

# %%
#VALORES NULOS
filtro["193_sales_planning_tools"] =filtro["193_sales_planning_tools"].fillna("--")
# Out:
# <ipython-input-54-db9ecaf9cc70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["193_sales_planning_tools"] =filtro["193_sales_planning_tools"].fillna("--")

# %%
#VALORES NULOS
filtro["62_frequency_only_services"] =filtro["62_frequency_only_services"].fillna("--")
# Out:
# <ipython-input-55-31b35cf6ed5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["62_frequency_only_services"] =filtro["62_frequency_only_services"].fillna("--")

# %%
#VALORES NULOS
filtro["77_delivery_timeslots"] =filtro["77_delivery_timeslots"].fillna("--")
# Out:
# <ipython-input-56-e868849705ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["77_delivery_timeslots"] =filtro["77_delivery_timeslots"].fillna("--")

# %%
#VALORES NULOS
filtro["44_willingness_inventory_management_suppliers"] =filtro["44_willingness_inventory_management_suppliers"].fillna("--")
# Out:
# <ipython-input-57-d45d8e668e16>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["44_willingness_inventory_management_suppliers"] =filtro["44_willingness_inventory_management_suppliers"].fillna("--")

# %%
#VALORES NULOS
filtro["45_willingness_reorder_suppliers"] =filtro["45_willingness_reorder_suppliers"].fillna("--")
# Out:
# <ipython-input-58-cd74d41b2971>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["45_willingness_reorder_suppliers"] =filtro["45_willingness_reorder_suppliers"].fillna("--")

# %%
#VALORES NULOS
filtro["46_willingness_reorder_suppliers_variety"] =filtro["46_willingness_reorder_suppliers_variety"].fillna("--")
# Out:
# <ipython-input-59-26b38e85fb6f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["46_willingness_reorder_suppliers_variety"] =filtro["46_willingness_reorder_suppliers_variety"].fillna("--")

# %%
#VALORES NULOS
filtro["279_changes_procurement_pandemic"] =filtro["279_changes_procurement_pandemic"].fillna("--")
# Out:
# <ipython-input-60-c1ee1694bc9f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["279_changes_procurement_pandemic"] =filtro["279_changes_procurement_pandemic"].fillna("--")

# %%
#VALORES NULOS
filtro["157_frequency_organize_shelves"] =filtro["157_frequency_organize_shelves"].fillna("--")
# Out:
# <ipython-input-61-224e6a40872d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["157_frequency_organize_shelves"] =filtro["157_frequency_organize_shelves"].fillna("--")

# %%
#VALORES NULOS
filtro["161_actions_stockouts"] =filtro["161_actions_stockouts"].fillna("--")
# Out:
# <ipython-input-62-e82f4cdede7d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["161_actions_stockouts"] =filtro["161_actions_stockouts"].fillna("--")

# %%
#VALORES NULOS
filtro["162_inventory_extra_space"] =filtro["162_inventory_extra_space"].fillna("--")
# Out:
# <ipython-input-63-c6ee322b01cd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["162_inventory_extra_space"] =filtro["162_inventory_extra_space"].fillna("--")

# %%
#VALORES NULOS
filtro["250_technology_investment_operations"] =filtro["250_technology_investment_operations"].fillna("--")
# Out:
# <ipython-input-64-e1974dde7824>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["250_technology_investment_operations"] =filtro["250_technology_investment_operations"].fillna("--")

# %%
#VALORES NULOS
filtro["251_technology_investment_customers"] =filtro["251_technology_investment_customers"].fillna("--")
# Out:
# <ipython-input-65-3046b6751686>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["251_technology_investment_customers"] =filtro["251_technology_investment_customers"].fillna("--")

# %%
#VALORES NULOS
filtro["254_technology_roadmap"] =filtro["254_technology_roadmap"].fillna("--")
# Out:
# <ipython-input-66-7a0c2c9d1689>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro["254_technology_roadmap"] =filtro["254_technology_roadmap"].fillna("--")

# %%
# VISUALIZACIÓN DEL DF COMPLETO
filtro
# Out:
#               _updated_by                232_type_of_store  \
# 0    Salomon Abdala Perez                           Tailor
# 1    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                    ...                              ...
# 166          Emilio Garza   Grocery store (aka. nanostore)
# 167          Emilio Garza   Grocery store (aka. nanostore)
# 168          Emilio Garza  Micro-restaurant (aka. fondita)
# 169        Francisco Adán  Micro-restaurant (aka. fondita)
# 170          Emilio Garza  Micro-restaurant (aka. fondita)
#
#                                      184_store_devices 103_number_own_fridges  \
# 0    POS system (i.e. computer + bar code scanner +...                     --
# 1                       Dataphone (i.e. card payments)                     --
# 2    Dataphone (i.e. card payments),POS system (i.e...                     --
# 3    POS system (i.e. computer + bar code scanner +...                     --
# 4                                           Smartphone                     --
# ..                                                 ...                    ...
# 166                    Analog cash register,Smartphone                     --
# 167                    Analog cash register,Smartphone                     --
# 168                                         Smartphone                     --
# 169                               Analog cash register                     --
# 170                                         Smartphone                     --
#
#     310_burnout 24_burnout 272_card_days_receive_money  \
# 0            no         --                          --
# 1            no         --                          --
# 2            no         --                         0.0
# 3            no         --                         0.0
# 4            no         --                         1.0
# ..          ...        ...                         ...
# 166          --         --                          --
# 167          --         --                          --
# 168          --         --                          --
# 169          --         --                          --
# 170          --         --                          --
#
#     193_sales_planning_tools 62_frequency_only_services 77_delivery_timeslots  \
# 0     Software especializado                         --                    --
# 1                         --                         --                    --
# 2                         --                         --                    --
# 3                    Ninguna                         --                    --
# 4                         --                         --                    --
# ..                       ...                        ...                   ...
# 166                       --                         --                    --
# 167                       --                         --                    --
# 168                       --                         --                    --
# 169                       --                         --                    --
# 170                       --                         --                    --
#
#     44_willingness_inventory_management_suppliers  \
# 0                                              --
# 1                                              --
# 2                                              --
# 3                                              --
# 4                                              --
# ..                                            ...
# 166                                            --
# 167                                            --
# 168                                            --
# 169                                            --
# 170                                            --
#
#     45_willingness_reorder_suppliers 46_willingness_reorder_suppliers_variety  \
# 0                                 --                                       --
# 1                                 --                                       --
# 2                                 --                                       --
# 3                                 --                                       --
# 4                                 --                                       --
# ..                               ...                                      ...
# 166                               --                                       --
# 167                               --                                       --
# 168                               --                                       --
# 169                               --                                       --
# 170                               --                                       --
#
#     279_changes_procurement_pandemic 157_frequency_organize_shelves  \
# 0                                 --                 Semestralmente
# 1                                 --                             --
# 2                                 --                   Semanalmente
# 3                                 --                   Semanalmente
# 4                                 --                   Mensualmente
# ..                               ...                            ...
# 166                               --                             --
# 167                               --                             --
# 168                               --                             --
# 169                               --                             --
# 170                               --                             --
#
#                                  161_actions_stockouts  \
# 0    Solicitar tiempo al cliente para conseguir el ...
# 1    Ofrecer un producto sustituto,Solicitar tiempo...
# 2                                      Perder la venta
# 3                        Ofrecer un producto sustituto
# 4    Informar al proveedor,Solicitar tiempo al clie...
# ..                                                 ...
# 166                                                 --
# 167                                                 --
# 168                                                 --
# 169                                                 --
# 170                                                 --
#
#     162_inventory_extra_space 250_technology_investment_operations  \
# 0                           0                                   --
# 1                         10%                                   --
# 2                         10%                                   --
# 3                           0                                   --
# 4                           0                                   --
# ..                        ...                                  ...
# 166                        --                                   --
# 167                        --                                   --
# 168                        --                                   --
# 169                        --                                   --
# 170                        --                                   --
#
#     251_technology_investment_customers 254_technology_roadmap
# 0                                    --                     --
# 1                                    --                     --
# 2                                    --                     --
# 3                                    --                     --
# 4                                    --                     --
# ..                                  ...                    ...
# 166                                  --                     --
# 167                                  --                     --
# 168                                  --                     --
# 169                                  --                     --
# 170                                  --                     --
#
# [171 rows x 20 columns]

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(filtro)
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# 11                       Ismael López          6    0.035088         0.766082
# 12                      Mauro Munguía          4    0.023392         0.789474
# 13                         Alan Bravo          4    0.023392         0.812865
# 14                     Sandra Carreón          4    0.023392         0.836257
# 15                        Jorge Mason          3    0.017544         0.853801
# 16                      Jesús Herrera          3    0.017544         0.871345
# 17              Ricardo Galindo Bulos          3    0.017544         0.888889
# 18                         Yael Loeza          2    0.011696         0.900585
# 19                      Manuel Flores          2    0.011696         0.912281
# 20                       Juan Spínola          2    0.011696         0.923977
# 21                      Azael Mendoza          2    0.011696         0.935673
# 22             Irvin Vásquez Figueroa          2    0.011696         0.947368
# 23    Sebastian Salem Barranco Olvera          2    0.011696         0.959064
# 24      Jesús Antonio Zapatero García          1    0.005848         0.964912
# 25                   Marino Gutiérrez          1    0.005848         0.970760
# 26             Ramón Alberto Gastélum          1    0.005848         0.976608
# 27                        Saúl Cuervo          1    0.005848         0.982456
# 28                       José Oropeza          1    0.005848         0.988304
# 29                          Luis Lara          1    0.005848         0.994152
# 30                     Daniel Serrano          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                     184_store_devices  frequency  percentage  \
# 0                                          Smartphone         52    0.304094
# 1                                Analog cash register         16    0.093567
# 2   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                     Analog cash register,Smartphone          8    0.046784
# 5                         Security cameras,Smartphone          7    0.040936
# 6   Dataphone (i.e. card payments),Security camera...          5    0.029240
# 7                                    Security cameras          5    0.029240
# 8   POS system (i.e. computer + bar code scanner +...          4    0.023392
# 9               Analog cash register,Security cameras          4    0.023392
# 10   Analog cash register,Security cameras,Smartphone          4    0.023392
# 11                     Dataphone (i.e. card payments)          4    0.023392
# 12  Dataphone (i.e. card payments),POS system (i.e...          3    0.017544
# 13    Dataphone (i.e. card payments),Security cameras          3    0.017544
# 14  Analog cash register,POS system (i.e. computer...          3    0.017544
# 15          Dataphone (i.e. card payments),Smartphone          3    0.017544
# 16  Analog cash register,POS system (i.e. computer...          3    0.017544
# 17  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 18                                               None          2    0.011696
# 19  POS system (i.e. computer + bar code scanner +...          2    0.011696
# 20  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 21  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 22  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 23  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 24                                                 no          1    0.005848
# 25  Dataphone (i.e. card payments),POS system (i.e...          1    0.005848
# 26  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 27  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 28                                           Nothing           1    0.005848
# 29                          acepta pagos en efectivo           1    0.005848
# 30  Analog cash register,POS system (i.e. computer...          1    0.005848
# 31                                    Papel y celular          1    0.005848
# 32                                 Pesa y calculadora          1    0.005848
# 33                        no cuenta con dispositivos           1    0.005848
# 34                                            ninguno          1    0.005848
# 35               Security cameras,bocina y ventilador          1    0.005848
# 36  POS system (i.e. computer + bar code scanner +...          1    0.005848
# 37  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 38                                           no tiene          1    0.005848
#
#     cumulative_perc
# 0          0.304094
# 1          0.397661
# 2          0.450292
# 3          0.502924
# 4          0.549708
# 5          0.590643
# 6          0.619883
# 7          0.649123
# 8          0.672515
# 9          0.695906
# 10         0.719298
# 11         0.742690
# 12         0.760234
# 13         0.777778
# 14         0.795322
# 15         0.812865
# 16         0.830409
# 17         0.842105
# 18         0.853801
# 19         0.865497
# 20         0.877193
# 21         0.888889
# 22         0.900585
# 23         0.912281
# 24         0.918129
# 25         0.923977
# 26         0.929825
# 27         0.935673
# 28         0.941520
# 29         0.947368
# 30         0.953216
# 31         0.959064
# 32         0.964912
# 33         0.970760
# 34         0.976608
# 35         0.982456
# 36         0.988304
# 37         0.994152
# 38         1.000000
#
# ----------------------------------------------------------------
#
#   103_number_own_fridges  frequency  percentage  cumulative_perc
# 0                     --        144    0.842105         0.842105
# 1                    0.0          8    0.046784         0.888889
# 2                    1.0          6    0.035088         0.923977
# 3                    2.0          6    0.035088         0.959064
# 4                    3.0          2    0.011696         0.970760
# 5                    7.0          2    0.011696         0.982456
# 6                    5.0          2    0.011696         0.994152
# 7                   20.0          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#   310_burnout  frequency  percentage  cumulative_perc
# 0          no         68    0.397661         0.397661
# 1          --         64    0.374269         0.771930
# 2         yes         39    0.228070         1.000000
#
# ----------------------------------------------------------------
#
#   24_burnout  frequency  percentage  cumulative_perc
# 0         --        133    0.777778         0.777778
# 1        7.0         11    0.064327         0.842105
# 2        3.0          9    0.052632         0.894737
# 3        2.0          6    0.035088         0.929825
# 4        1.0          4    0.023392         0.953216
# 5        4.0          3    0.017544         0.970760
# 6        5.0          3    0.017544         0.988304
# 7        6.0          2    0.011696         1.000000
#
# ----------------------------------------------------------------
#
#   272_card_days_receive_money  frequency  percentage  cumulative_perc
# 0                          --        127    0.742690         0.742690
# 1                         1.0         30    0.175439         0.918129
# 2                         0.0         10    0.058480         0.976608
# 3                         3.0          2    0.011696         0.988304
# 4                         2.0          1    0.005848         0.994152
# 5                         5.0          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#                    193_sales_planning_tools  frequency  percentage  \
# 0                                        --         89    0.520468
# 1                                   Ninguna         33    0.192982
# 2                                  Cuaderno         21    0.122807
# 3                    Software especializado          6    0.035088
# 4                                     Excel          6    0.035088
# 5                            Cuaderno,Excel          3    0.017544
# 6                          Cuaderno,Ninguna          2    0.011696
# 7                                     Other          1    0.005848
# 8                                    Mental          1    0.005848
# 9                      Por temporada de pan          1    0.005848
# 10                           Sobre demanda           1    0.005848
# 11  Aplicación móvil,Software especializado          1    0.005848
# 12             Excel,Software especializado          1    0.005848
# 13                                Catálogo           1    0.005848
# 14                           Redes sociales          1    0.005848
# 15                         Aplicación móvil          1    0.005848
# 16                               En físico           1    0.005848
# 17                   Aplicación móvil,Excel          1    0.005848
#
#     cumulative_perc
# 0          0.520468
# 1          0.713450
# 2          0.836257
# 3          0.871345
# 4          0.906433
# 5          0.923977
# 6          0.935673
# 7          0.941520
# 8          0.947368
# 9          0.953216
# 10         0.959064
# 11         0.964912
# 12         0.970760
# 13         0.976608
# 14         0.982456
# 15         0.988304
# 16         0.994152
# 17         1.000000
#
# ----------------------------------------------------------------
#
#    62_frequency_only_services  frequency  percentage  cumulative_perc
# 0                          --        147    0.859649         0.859649
# 1                         0.0          7    0.040936         0.900585
# 2                         2.0          4    0.023392         0.923977
# 3                         1.0          4    0.023392         0.947368
# 4                         7.0          2    0.011696         0.959064
# 5                         4.0          1    0.005848         0.964912
# 6                        28.0          1    0.005848         0.970760
# 7                       100.0          1    0.005848         0.976608
# 8                        50.0          1    0.005848         0.982456
# 9                         5.0          1    0.005848         0.988304
# 10                        3.0          1    0.005848         0.994152
# 11                       35.0          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#      77_delivery_timeslots  frequency  percentage  cumulative_perc
# 0                       --        169    0.988304         0.988304
# 1  Tarde (12:00 - 7:00 pm)          2    0.011696         1.000000
#
# ----------------------------------------------------------------
#
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                                            --         92    0.538012
# 1                      Totalmente en desacuerdo         58    0.339181
# 2                            Algo en desacuerdo          8    0.046784
# 3                Ni de acuerdo ni en desacuerdo          5    0.029240
# 4                               Algo de acuerdo          5    0.029240
# 5                         Totalmente de acuerdo          3    0.017544
#
#    cumulative_perc
# 0         0.538012
# 1         0.877193
# 2         0.923977
# 3         0.953216
# 4         0.982456
# 5         1.000000
#
# ----------------------------------------------------------------
#
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0                               --         94    0.549708         0.549708
# 1         Totalmente en desacuerdo         40    0.233918         0.783626
# 2                  Algo de acuerdo         12    0.070175         0.853801
# 3               Algo en desacuerdo         10    0.058480         0.912281
# 4            Totalmente de acuerdo          9    0.052632         0.964912
# 5   Ni de acuerdo ni en desacuerdo          6    0.035088         1.000000
#
# ----------------------------------------------------------------
#
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                                       --         97    0.567251
# 1                 Totalmente en desacuerdo         33    0.192982
# 2                    Totalmente de acuerdo         15    0.087719
# 3                          Algo de acuerdo         14    0.081871
# 4                       Algo en desacuerdo          7    0.040936
# 5           Ni de acuerdo ni en desacuerdo          5    0.029240
#
#    cumulative_perc
# 0         0.567251
# 1         0.760234
# 2         0.847953
# 3         0.929825
# 4         0.970760
# 5         1.000000
#
# ----------------------------------------------------------------
#
#                     279_changes_procurement_pandemic  frequency  percentage  \
# 0                                                 --        148    0.865497
# 1  Disminución de la variedad de productos,Dismin...          6    0.035088
# 2  Disminuir la cantidad del pedido,Disminuir la ...          3    0.017544
# 3                   Disminuir la cantidad del pedido          3    0.017544
# 4                          Ninguna de las anteriores          3    0.017544
# 5                 Disminuir la frecuencia de pedidos          3    0.017544
# 6  Aumentar la variedad de productos.,Disminuir l...          2    0.011696
# 7                 Aumentar la variedad de productos.          1    0.005848
# 8  Aumentar la cantidad del pedido,Disminución de...          1    0.005848
# 9                    Aumentar la cantidad del pedido          1    0.005848
#
#    cumulative_perc
# 0         0.865497
# 1         0.900585
# 2         0.918129
# 3         0.935673
# 4         0.953216
# 5         0.970760
# 6         0.982456
# 7         0.988304
# 8         0.994152
# 9         1.000000
#
# ----------------------------------------------------------------
#
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                             --         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304
# 7                 Semestralmente          1    0.005848         0.994152
# 8                    No se tiene          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#                                 161_actions_stockouts  frequency  percentage  \
# 0                                                  --         79    0.461988
# 1   Solicitar tiempo al cliente para conseguir el ...         31    0.181287
# 2                       Ofrecer un producto sustituto         20    0.116959
# 3   Ofrecer un producto sustituto,Solicitar tiempo...         12    0.070175
# 4                                     Perder la venta          8    0.046784
# 5   Informar al proveedor,Solicitar tiempo al clie...          5    0.029240
# 6                               Informar al proveedor          5    0.029240
# 7   Informar al proveedor,Ofrecer un producto sust...          3    0.017544
# 8   Informar al proveedor,Ofrecer un producto sust...          2    0.011696
# 9               Informar al proveedor,Perder la venta          2    0.011696
# 10            Descuento,Ofrecer un producto sustituto          1    0.005848
# 11      Ofrecer un producto sustituto,Perder la venta          1    0.005848
# 12                                            apuntar          1    0.005848
# 13  Informar al proveedor,Ofrecer un producto sust...          1    0.005848
#
#     cumulative_perc
# 0          0.461988
# 1          0.643275
# 2          0.760234
# 3          0.830409
# 4          0.877193
# 5          0.906433
# 6          0.935673
# 7          0.953216
# 8          0.964912
# 9          0.976608
# 10         0.982456
# 11         0.988304
# 12         0.994152
# 13         1.000000
#
# ----------------------------------------------------------------
#
#   162_inventory_extra_space  frequency  percentage  cumulative_perc
# 0                        --         82    0.479532         0.479532
# 1                         0         29    0.169591         0.649123
# 2                       20%         20    0.116959         0.766082
# 3                       10%         17    0.099415         0.865497
# 4                       30%         10    0.058480         0.923977
# 5                     50% +          9    0.052632         0.976608
# 6                       40%          3    0.017544         0.994152
# 7                        2%          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                                   --         97    0.567251         0.567251
# 1                Totalmente de acuerdo         34    0.198830         0.766082
# 2                           De acuerdo         20    0.116959         0.883041
# 3             Totalmente en desacuerdo          8    0.046784         0.929825
# 4                        En desacuerdo          6    0.035088         0.964912
# 5       Ni de acuerdo ni en desacuerdo          6    0.035088         1.000000
#
# ----------------------------------------------------------------
#
#   251_technology_investment_customers  frequency  percentage  cumulative_perc
# 0                                  --         98    0.573099         0.573099
# 1               Totalmente de acuerdo         35    0.204678         0.777778
# 2                          De acuerdo         23    0.134503         0.912281
# 3            Totalmente en desacuerdo          7    0.040936         0.953216
# 4      Ni de acuerdo ni en desacuerdo          5    0.029240         0.982456
# 5                       En desacuerdo          3    0.017544         1.000000
#
# ----------------------------------------------------------------
#
#            254_technology_roadmap  frequency  percentage  cumulative_perc
# 0                              --        100    0.584795         0.584795
# 1        Totalmente en desacuerdo         32    0.187135         0.771930
# 2           Totalmente de acuerdo         12    0.070175         0.842105
# 3                      De acuerdo         11    0.064327         0.906433
# 4  Ni de acuerdo ni en desacuerdo          9    0.052632         0.959064
# 5                   En desacuerdo          7    0.040936         1.000000
#
# ----------------------------------------------------------------

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna _updated_by
table1= freq_tbl(filtro['_updated_by'])
table1
# Out:
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# 11                       Ismael López          6    0.035088         0.766082
# 12                      Mauro Munguía          4    0.023392         0.789474
# 13                         Alan Bravo          4    0.023392         0.812865
# 14                     Sandra Carreón          4    0.023392         0.836257
# 15                        Jorge Mason          3    0.017544         0.853801
# 16                      Jesús Herrera          3    0.017544         0.871345
# 17              Ricardo Galindo Bulos          3    0.017544         0.888889
# 18                         Yael Loeza          2    0.011696         0.900585
# 19                      Manuel Flores          2    0.011696         0.912281
# 20                       Juan Spínola          2    0.011696         0.923977
# 21                      Azael Mendoza          2    0.011696         0.935673
# 22             Irvin Vásquez Figueroa          2    0.011696         0.947368
# 23    Sebastian Salem Barranco Olvera          2    0.011696         0.959064
# 24      Jesús Antonio Zapatero García          1    0.005848         0.964912
# 25                   Marino Gutiérrez          1    0.005848         0.970760
# 26             Ramón Alberto Gastélum          1    0.005848         0.976608
# 27                        Saúl Cuervo          1    0.005848         0.982456
# 28                       José Oropeza          1    0.005848         0.988304
# 29                          Luis Lara          1    0.005848         0.994152
# 30                     Daniel Serrano          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#                          _updated_by  frequency  percentage  cumulative_perc
# 0               Salomon Abdala Perez         20    0.116959         0.116959
# 1  Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                        José Zapata         14    0.081871         0.292398
# 3                       Emilio Garza         13    0.076023         0.368421
# 4                   Benjamin Barbosa         13    0.076023         0.444444
# 5                    Pedro Contreras         12    0.070175         0.514620

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('_updated_by')
Filtro_index
# Out:
#                                    frequency  percentage  cumulative_perc
# _updated_by
# Salomon Abdala Perez                      20    0.116959         0.116959
# Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# José Zapata                               14    0.081871         0.292398
# Emilio Garza                              13    0.076023         0.368421
# Benjamin Barbosa                          13    0.076023         0.444444
# Pedro Contreras                           12    0.070175         0.514620

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 232_type_of_store
table1= freq_tbl(filtro['232_type_of_store'])
table1
# Out:
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>6]
Filtro
# Out:
#                  232_type_of_store  frequency  percentage  cumulative_perc
# 0   Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1  Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                   Dairy products         10    0.058480         0.543860

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('232_type_of_store')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 232_type_of_store
# Grocery store (aka. nanostore)          52    0.304094         0.304094
# Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# Dairy products                          10    0.058480         0.543860

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 184_store_devices
table1= freq_tbl(filtro['184_store_devices'])
table1
# Out:
#                                     184_store_devices  frequency  percentage  \
# 0                                          Smartphone         52    0.304094
# 1                                Analog cash register         16    0.093567
# 2   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                     Analog cash register,Smartphone          8    0.046784
# 5                         Security cameras,Smartphone          7    0.040936
# 6   Dataphone (i.e. card payments),Security camera...          5    0.029240
# 7                                    Security cameras          5    0.029240
# 8   POS system (i.e. computer + bar code scanner +...          4    0.023392
# 9               Analog cash register,Security cameras          4    0.023392
# 10   Analog cash register,Security cameras,Smartphone          4    0.023392
# 11                     Dataphone (i.e. card payments)          4    0.023392
# 12  Dataphone (i.e. card payments),POS system (i.e...          3    0.017544
# 13    Dataphone (i.e. card payments),Security cameras          3    0.017544
# 14  Analog cash register,POS system (i.e. computer...          3    0.017544
# 15          Dataphone (i.e. card payments),Smartphone          3    0.017544
# 16  Analog cash register,POS system (i.e. computer...          3    0.017544
# 17  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 18                                               None          2    0.011696
# 19  POS system (i.e. computer + bar code scanner +...          2    0.011696
# 20  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 21  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 22  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 23  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 24                                                 no          1    0.005848
# 25  Dataphone (i.e. card payments),POS system (i.e...          1    0.005848
# 26  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 27  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 28                                           Nothing           1    0.005848
# 29                          acepta pagos en efectivo           1    0.005848
# 30  Analog cash register,POS system (i.e. computer...          1    0.005848
# 31                                    Papel y celular          1    0.005848
# 32                                 Pesa y calculadora          1    0.005848
# 33                        no cuenta con dispositivos           1    0.005848
# 34                                            ninguno          1    0.005848
# 35               Security cameras,bocina y ventilador          1    0.005848
# 36  POS system (i.e. computer + bar code scanner +...          1    0.005848
# 37  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 38                                           no tiene          1    0.005848
#
#     cumulative_perc
# 0          0.304094
# 1          0.397661
# 2          0.450292
# 3          0.502924
# 4          0.549708
# 5          0.590643
# 6          0.619883
# 7          0.649123
# 8          0.672515
# 9          0.695906
# 10         0.719298
# 11         0.742690
# 12         0.760234
# 13         0.777778
# 14         0.795322
# 15         0.812865
# 16         0.830409
# 17         0.842105
# 18         0.853801
# 19         0.865497
# 20         0.877193
# 21         0.888889
# 22         0.900585
# 23         0.912281
# 24         0.918129
# 25         0.923977
# 26         0.929825
# 27         0.935673
# 28         0.941520
# 29         0.947368
# 30         0.953216
# 31         0.959064
# 32         0.964912
# 33         0.970760
# 34         0.976608
# 35         0.982456
# 36         0.988304
# 37         0.994152
# 38         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>7]
Filtro
# Out:
#                                    184_store_devices  frequency  percentage  \
# 0                                         Smartphone         52    0.304094
# 1                               Analog cash register         16    0.093567
# 2  POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3  POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                    Analog cash register,Smartphone          8    0.046784
#
#    cumulative_perc
# 0         0.304094
# 1         0.397661
# 2         0.450292
# 3         0.502924
# 4         0.549708

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('184_store_devices')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 184_store_devices
# Smartphone                                                 52    0.304094
# Analog cash register                                       16    0.093567
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# POS system (i.e. computer + bar code scanner + ...          9    0.052632
# Analog cash register,Smartphone                             8    0.046784
#
#                                                     cumulative_perc
# 184_store_devices
# Smartphone                                                 0.304094
# Analog cash register                                       0.397661
# POS system (i.e. computer + bar code scanner + ...         0.450292
# POS system (i.e. computer + bar code scanner + ...         0.502924
# Analog cash register,Smartphone                            0.549708

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 103_number_own_fridges
table1= freq_tbl(filtro['103_number_own_fridges'])
table1
# Out:
#   103_number_own_fridges  frequency  percentage  cumulative_perc
# 0                     --        144    0.842105         0.842105
# 1                    0.0          8    0.046784         0.888889
# 2                    1.0          6    0.035088         0.923977
# 3                    2.0          6    0.035088         0.959064
# 4                    3.0          2    0.011696         0.970760
# 5                    7.0          2    0.011696         0.982456
# 6                    5.0          2    0.011696         0.994152
# 7                   20.0          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   103_number_own_fridges  frequency  percentage  cumulative_perc
# 0                     --        144    0.842105         0.842105
# 1                    0.0          8    0.046784         0.888889
# 2                    1.0          6    0.035088         0.923977
# 3                    2.0          6    0.035088         0.959064

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('103_number_own_fridges')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# 103_number_own_fridges
# --                            144    0.842105         0.842105
# 0.0                             8    0.046784         0.888889
# 1.0                             6    0.035088         0.923977
# 2.0                             6    0.035088         0.959064

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 310_burnout
table1= freq_tbl(filtro['310_burnout'])
table1
# Out:
#   310_burnout  frequency  percentage  cumulative_perc
# 0          no         68    0.397661         0.397661
# 1          --         64    0.374269         0.771930
# 2         yes         39    0.228070         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   310_burnout  frequency  percentage  cumulative_perc
# 0          no         68    0.397661         0.397661
# 1          --         64    0.374269         0.771930
# 2         yes         39    0.228070         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('310_burnout')
Filtro_index
# Out:
#              frequency  percentage  cumulative_perc
# 310_burnout
# no                  68    0.397661         0.397661
# --                  64    0.374269         0.771930
# yes                 39    0.228070         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 24_burnout
table1= freq_tbl(filtro['24_burnout'])
table1
# Out:
#   24_burnout  frequency  percentage  cumulative_perc
# 0         --        133    0.777778         0.777778
# 1        7.0         11    0.064327         0.842105
# 2        3.0          9    0.052632         0.894737
# 3        2.0          6    0.035088         0.929825
# 4        1.0          4    0.023392         0.953216
# 5        4.0          3    0.017544         0.970760
# 6        5.0          3    0.017544         0.988304
# 7        6.0          2    0.011696         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   24_burnout  frequency  percentage  cumulative_perc
# 0         --        133    0.777778         0.777778
# 1        7.0         11    0.064327         0.842105
# 2        3.0          9    0.052632         0.894737
# 3        2.0          6    0.035088         0.929825

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('24_burnout')
Filtro_index
# Out:
#             frequency  percentage  cumulative_perc
# 24_burnout
# --                133    0.777778         0.777778
# 7.0                11    0.064327         0.842105
# 3.0                 9    0.052632         0.894737
# 2.0                 6    0.035088         0.929825

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 272_card_days_receive_money
table1= freq_tbl(filtro['272_card_days_receive_money'])
table1
# Out:
#   272_card_days_receive_money  frequency  percentage  cumulative_perc
# 0                          --        127    0.742690         0.742690
# 1                         1.0         30    0.175439         0.918129
# 2                         0.0         10    0.058480         0.976608
# 3                         3.0          2    0.011696         0.988304
# 4                         2.0          1    0.005848         0.994152
# 5                         5.0          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   272_card_days_receive_money  frequency  percentage  cumulative_perc
# 0                          --        127    0.742690         0.742690
# 1                         1.0         30    0.175439         0.918129
# 2                         0.0         10    0.058480         0.976608

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('272_card_days_receive_money')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# 272_card_days_receive_money
# --                                 127    0.742690         0.742690
# 1.0                                 30    0.175439         0.918129
# 0.0                                 10    0.058480         0.976608

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 193_sales_planning_tools
table1= freq_tbl(filtro['193_sales_planning_tools'])
table1
# Out:
#                    193_sales_planning_tools  frequency  percentage  \
# 0                                        --         89    0.520468
# 1                                   Ninguna         33    0.192982
# 2                                  Cuaderno         21    0.122807
# 3                    Software especializado          6    0.035088
# 4                                     Excel          6    0.035088
# 5                            Cuaderno,Excel          3    0.017544
# 6                          Cuaderno,Ninguna          2    0.011696
# 7                                     Other          1    0.005848
# 8                                    Mental          1    0.005848
# 9                      Por temporada de pan          1    0.005848
# 10                           Sobre demanda           1    0.005848
# 11  Aplicación móvil,Software especializado          1    0.005848
# 12             Excel,Software especializado          1    0.005848
# 13                                Catálogo           1    0.005848
# 14                           Redes sociales          1    0.005848
# 15                         Aplicación móvil          1    0.005848
# 16                               En físico           1    0.005848
# 17                   Aplicación móvil,Excel          1    0.005848
#
#     cumulative_perc
# 0          0.520468
# 1          0.713450
# 2          0.836257
# 3          0.871345
# 4          0.906433
# 5          0.923977
# 6          0.935673
# 7          0.941520
# 8          0.947368
# 9          0.953216
# 10         0.959064
# 11         0.964912
# 12         0.970760
# 13         0.976608
# 14         0.982456
# 15         0.988304
# 16         0.994152
# 17         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   193_sales_planning_tools  frequency  percentage  cumulative_perc
# 0                       --         89    0.520468         0.520468
# 1                  Ninguna         33    0.192982         0.713450
# 2                 Cuaderno         21    0.122807         0.836257
# 3   Software especializado          6    0.035088         0.871345
# 4                    Excel          6    0.035088         0.906433

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('193_sales_planning_tools')
Filtro_index
# Out:
#                           frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# --                               89    0.520468         0.520468
# Ninguna                          33    0.192982         0.713450
# Cuaderno                         21    0.122807         0.836257
# Software especializado            6    0.035088         0.871345
# Excel                             6    0.035088         0.906433

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 62_frequency_only_services
table1= freq_tbl(filtro['62_frequency_only_services'])
table1
# Out:
#    62_frequency_only_services  frequency  percentage  cumulative_perc
# 0                          --        147    0.859649         0.859649
# 1                         0.0          7    0.040936         0.900585
# 2                         2.0          4    0.023392         0.923977
# 3                         1.0          4    0.023392         0.947368
# 4                         7.0          2    0.011696         0.959064
# 5                         4.0          1    0.005848         0.964912
# 6                        28.0          1    0.005848         0.970760
# 7                       100.0          1    0.005848         0.976608
# 8                        50.0          1    0.005848         0.982456
# 9                         5.0          1    0.005848         0.988304
# 10                        3.0          1    0.005848         0.994152
# 11                       35.0          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>3]
Filtro
# Out:
#   62_frequency_only_services  frequency  percentage  cumulative_perc
# 0                         --        147    0.859649         0.859649
# 1                        0.0          7    0.040936         0.900585
# 2                        2.0          4    0.023392         0.923977
# 3                        1.0          4    0.023392         0.947368

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('62_frequency_only_services')
Filtro_index
# Out:
#                             frequency  percentage  cumulative_perc
# 62_frequency_only_services
# --                                147    0.859649         0.859649
# 0.0                                 7    0.040936         0.900585
# 2.0                                 4    0.023392         0.923977
# 1.0                                 4    0.023392         0.947368

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 77_delivery_timeslots
table1= freq_tbl(filtro['77_delivery_timeslots'])
table1
# Out:
#      77_delivery_timeslots  frequency  percentage  cumulative_perc
# 0                       --        169    0.988304         0.988304
# 1  Tarde (12:00 - 7:00 pm)          2    0.011696         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#      77_delivery_timeslots  frequency  percentage  cumulative_perc
# 0                       --        169    0.988304         0.988304
# 1  Tarde (12:00 - 7:00 pm)          2    0.011696         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('77_delivery_timeslots')
Filtro_index
# Out:
#                          frequency  percentage  cumulative_perc
# 77_delivery_timeslots
# --                             169    0.988304         0.988304
# Tarde (12:00 - 7:00 pm)          2    0.011696         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 44_willingness_inventory_management_suppliers
table1= freq_tbl(filtro['44_willingness_inventory_management_suppliers'])
table1
# Out:
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                                            --         92    0.538012
# 1                      Totalmente en desacuerdo         58    0.339181
# 2                            Algo en desacuerdo          8    0.046784
# 3                Ni de acuerdo ni en desacuerdo          5    0.029240
# 4                               Algo de acuerdo          5    0.029240
# 5                         Totalmente de acuerdo          3    0.017544
#
#    cumulative_perc
# 0         0.538012
# 1         0.877193
# 2         0.923977
# 3         0.953216
# 4         0.982456
# 5         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>4]
Filtro
# Out:
#   44_willingness_inventory_management_suppliers  frequency  percentage  \
# 0                                            --         92    0.538012
# 1                      Totalmente en desacuerdo         58    0.339181
# 2                            Algo en desacuerdo          8    0.046784
# 3                Ni de acuerdo ni en desacuerdo          5    0.029240
# 4                               Algo de acuerdo          5    0.029240
#
#    cumulative_perc
# 0         0.538012
# 1         0.877193
# 2         0.923977
# 3         0.953216
# 4         0.982456

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('44_willingness_inventory_management_suppliers')
Filtro_index
# Out:
#                                                frequency  percentage  \
# 44_willingness_inventory_management_suppliers
# --                                                    92    0.538012
# Totalmente en desacuerdo                              58    0.339181
# Algo en desacuerdo                                     8    0.046784
# Ni de acuerdo ni en desacuerdo                         5    0.029240
# Algo de acuerdo                                        5    0.029240
#
#                                                cumulative_perc
# 44_willingness_inventory_management_suppliers
# --                                                    0.538012
# Totalmente en desacuerdo                              0.877193
# Algo en desacuerdo                                    0.923977
# Ni de acuerdo ni en desacuerdo                        0.953216
# Algo de acuerdo                                       0.982456

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 45_willingness_reorder_suppliers
table1= freq_tbl(filtro['45_willingness_reorder_suppliers'])
table1
# Out:
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0                               --         94    0.549708         0.549708
# 1         Totalmente en desacuerdo         40    0.233918         0.783626
# 2                  Algo de acuerdo         12    0.070175         0.853801
# 3               Algo en desacuerdo         10    0.058480         0.912281
# 4            Totalmente de acuerdo          9    0.052632         0.964912
# 5   Ni de acuerdo ni en desacuerdo          6    0.035088         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#   45_willingness_reorder_suppliers  frequency  percentage  cumulative_perc
# 0                               --         94    0.549708         0.549708
# 1         Totalmente en desacuerdo         40    0.233918         0.783626
# 2                  Algo de acuerdo         12    0.070175         0.853801

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('45_willingness_reorder_suppliers')
Filtro_index
# Out:
#                                   frequency  percentage  cumulative_perc
# 45_willingness_reorder_suppliers
# --                                       94    0.549708         0.549708
# Totalmente en desacuerdo                 40    0.233918         0.783626
# Algo de acuerdo                          12    0.070175         0.853801

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 46_willingness_reorder_suppliers_variety
table1= freq_tbl(filtro['46_willingness_reorder_suppliers_variety'])
table1
# Out:
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                                       --         97    0.567251
# 1                 Totalmente en desacuerdo         33    0.192982
# 2                    Totalmente de acuerdo         15    0.087719
# 3                          Algo de acuerdo         14    0.081871
# 4                       Algo en desacuerdo          7    0.040936
# 5           Ni de acuerdo ni en desacuerdo          5    0.029240
#
#    cumulative_perc
# 0         0.567251
# 1         0.760234
# 2         0.847953
# 3         0.929825
# 4         0.970760
# 5         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#   46_willingness_reorder_suppliers_variety  frequency  percentage  \
# 0                                       --         97    0.567251
# 1                 Totalmente en desacuerdo         33    0.192982
# 2                    Totalmente de acuerdo         15    0.087719
# 3                          Algo de acuerdo         14    0.081871
#
#    cumulative_perc
# 0         0.567251
# 1         0.760234
# 2         0.847953
# 3         0.929825

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('46_willingness_reorder_suppliers_variety')
Filtro_index
# Out:
#                                           frequency  percentage  \
# 46_willingness_reorder_suppliers_variety
# --                                               97    0.567251
# Totalmente en desacuerdo                         33    0.192982
# Totalmente de acuerdo                            15    0.087719
# Algo de acuerdo                                  14    0.081871
#
#                                           cumulative_perc
# 46_willingness_reorder_suppliers_variety
# --                                               0.567251
# Totalmente en desacuerdo                         0.760234
# Totalmente de acuerdo                            0.847953
# Algo de acuerdo                                  0.929825

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 279_changes_procurement_pandemic
table1= freq_tbl(filtro['279_changes_procurement_pandemic'])
table1
# Out:
#                     279_changes_procurement_pandemic  frequency  percentage  \
# 0                                                 --        148    0.865497
# 1  Disminución de la variedad de productos,Dismin...          6    0.035088
# 2  Disminuir la cantidad del pedido,Disminuir la ...          3    0.017544
# 3                   Disminuir la cantidad del pedido          3    0.017544
# 4                          Ninguna de las anteriores          3    0.017544
# 5                 Disminuir la frecuencia de pedidos          3    0.017544
# 6  Aumentar la variedad de productos.,Disminuir l...          2    0.011696
# 7                 Aumentar la variedad de productos.          1    0.005848
# 8  Aumentar la cantidad del pedido,Disminución de...          1    0.005848
# 9                    Aumentar la cantidad del pedido          1    0.005848
#
#    cumulative_perc
# 0         0.865497
# 1         0.900585
# 2         0.918129
# 3         0.935673
# 4         0.953216
# 5         0.970760
# 6         0.982456
# 7         0.988304
# 8         0.994152
# 9         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>2]
Filtro
# Out:
#                     279_changes_procurement_pandemic  frequency  percentage  \
# 0                                                 --        148    0.865497
# 1  Disminución de la variedad de productos,Dismin...          6    0.035088
# 2  Disminuir la cantidad del pedido,Disminuir la ...          3    0.017544
# 3                   Disminuir la cantidad del pedido          3    0.017544
# 4                          Ninguna de las anteriores          3    0.017544
# 5                 Disminuir la frecuencia de pedidos          3    0.017544
#
#    cumulative_perc
# 0         0.865497
# 1         0.900585
# 2         0.918129
# 3         0.935673
# 4         0.953216
# 5         0.970760

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('279_changes_procurement_pandemic')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 279_changes_procurement_pandemic
# --                                                        148    0.865497
# Disminución de la variedad de productos,Disminu...          6    0.035088
# Disminuir la cantidad del pedido,Disminuir la f...          3    0.017544
# Disminuir la cantidad del pedido                            3    0.017544
# Ninguna de las anteriores                                   3    0.017544
# Disminuir la frecuencia de pedidos                          3    0.017544
#
#                                                     cumulative_perc
# 279_changes_procurement_pandemic
# --                                                         0.865497
# Disminución de la variedad de productos,Disminu...         0.900585
# Disminuir la cantidad del pedido,Disminuir la f...         0.918129
# Disminuir la cantidad del pedido                           0.935673
# Ninguna de las anteriores                                  0.953216
# Disminuir la frecuencia de pedidos                         0.970760

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 157_frequency_organize_shelves
table1= freq_tbl(filtro['157_frequency_organize_shelves'])
table1
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                             --         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304
# 7                 Semestralmente          1    0.005848         0.994152
# 8                    No se tiene          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                             --         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('157_frequency_organize_shelves')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# --                                     75    0.438596         0.438596
# Semanalmente                           40    0.233918         0.672515
# Diariamente                            32    0.187135         0.859649
# Nunca                                   8    0.046784         0.906433
# Mensualmente                            7    0.040936         0.947368

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 161_actions_stockouts
table1= freq_tbl(filtro['161_actions_stockouts'])
table1
# Out:
#                                 161_actions_stockouts  frequency  percentage  \
# 0                                                  --         79    0.461988
# 1   Solicitar tiempo al cliente para conseguir el ...         31    0.181287
# 2                       Ofrecer un producto sustituto         20    0.116959
# 3   Ofrecer un producto sustituto,Solicitar tiempo...         12    0.070175
# 4                                     Perder la venta          8    0.046784
# 5   Informar al proveedor,Solicitar tiempo al clie...          5    0.029240
# 6                               Informar al proveedor          5    0.029240
# 7   Informar al proveedor,Ofrecer un producto sust...          3    0.017544
# 8   Informar al proveedor,Ofrecer un producto sust...          2    0.011696
# 9               Informar al proveedor,Perder la venta          2    0.011696
# 10            Descuento,Ofrecer un producto sustituto          1    0.005848
# 11      Ofrecer un producto sustituto,Perder la venta          1    0.005848
# 12                                            apuntar          1    0.005848
# 13  Informar al proveedor,Ofrecer un producto sust...          1    0.005848
#
#     cumulative_perc
# 0          0.461988
# 1          0.643275
# 2          0.760234
# 3          0.830409
# 4          0.877193
# 5          0.906433
# 6          0.935673
# 7          0.953216
# 8          0.964912
# 9          0.976608
# 10         0.982456
# 11         0.988304
# 12         0.994152
# 13         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#                                161_actions_stockouts  frequency  percentage  \
# 0                                                 --         79    0.461988
# 1  Solicitar tiempo al cliente para conseguir el ...         31    0.181287
# 2                      Ofrecer un producto sustituto         20    0.116959
# 3  Ofrecer un producto sustituto,Solicitar tiempo...         12    0.070175
# 4                                    Perder la venta          8    0.046784
#
#    cumulative_perc
# 0         0.461988
# 1         0.643275
# 2         0.760234
# 3         0.830409
# 4         0.877193

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('161_actions_stockouts')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 161_actions_stockouts
# --                                                         79    0.461988
# Solicitar tiempo al cliente para conseguir el p...         31    0.181287
# Ofrecer un producto sustituto                              20    0.116959
# Ofrecer un producto sustituto,Solicitar tiempo ...         12    0.070175
# Perder la venta                                             8    0.046784
#
#                                                     cumulative_perc
# 161_actions_stockouts
# --                                                         0.461988
# Solicitar tiempo al cliente para conseguir el p...         0.643275
# Ofrecer un producto sustituto                              0.760234
# Ofrecer un producto sustituto,Solicitar tiempo ...         0.830409
# Perder la venta                                            0.877193

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 162_inventory_extra_space
table1= freq_tbl(filtro['162_inventory_extra_space'])
table1
# Out:
#   162_inventory_extra_space  frequency  percentage  cumulative_perc
# 0                        --         82    0.479532         0.479532
# 1                         0         29    0.169591         0.649123
# 2                       20%         20    0.116959         0.766082
# 3                       10%         17    0.099415         0.865497
# 4                       30%         10    0.058480         0.923977
# 5                     50% +          9    0.052632         0.976608
# 6                       40%          3    0.017544         0.994152
# 7                        2%          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#   162_inventory_extra_space  frequency  percentage  cumulative_perc
# 0                        --         82    0.479532         0.479532
# 1                         0         29    0.169591         0.649123
# 2                       20%         20    0.116959         0.766082
# 3                       10%         17    0.099415         0.865497

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('162_inventory_extra_space')
Filtro_index
# Out:
#                            frequency  percentage  cumulative_perc
# 162_inventory_extra_space
# --                                82    0.479532         0.479532
# 0                                 29    0.169591         0.649123
# 20%                               20    0.116959         0.766082
# 10%                               17    0.099415         0.865497

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 250_technology_investment_operations
table1= freq_tbl(filtro['250_technology_investment_operations'])
table1
# Out:
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                                   --         97    0.567251         0.567251
# 1                Totalmente de acuerdo         34    0.198830         0.766082
# 2                           De acuerdo         20    0.116959         0.883041
# 3             Totalmente en desacuerdo          8    0.046784         0.929825
# 4                        En desacuerdo          6    0.035088         0.964912
# 5       Ni de acuerdo ni en desacuerdo          6    0.035088         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#   250_technology_investment_operations  frequency  percentage  cumulative_perc
# 0                                   --         97    0.567251         0.567251
# 1                Totalmente de acuerdo         34    0.198830         0.766082
# 2                           De acuerdo         20    0.116959         0.883041

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('250_technology_investment_operations')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 250_technology_investment_operations
# --                                           97    0.567251         0.567251
# Totalmente de acuerdo                        34    0.198830         0.766082
# De acuerdo                                   20    0.116959         0.883041

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 251_technology_investment_customers
table1= freq_tbl(filtro['251_technology_investment_customers'])
table1
# Out:
#   251_technology_investment_customers  frequency  percentage  cumulative_perc
# 0                                  --         98    0.573099         0.573099
# 1               Totalmente de acuerdo         35    0.204678         0.777778
# 2                          De acuerdo         23    0.134503         0.912281
# 3            Totalmente en desacuerdo          7    0.040936         0.953216
# 4      Ni de acuerdo ni en desacuerdo          5    0.029240         0.982456
# 5                       En desacuerdo          3    0.017544         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>5]
Filtro
# Out:
#   251_technology_investment_customers  frequency  percentage  cumulative_perc
# 0                                  --         98    0.573099         0.573099
# 1               Totalmente de acuerdo         35    0.204678         0.777778
# 2                          De acuerdo         23    0.134503         0.912281
# 3            Totalmente en desacuerdo          7    0.040936         0.953216

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('251_technology_investment_customers')
Filtro_index
# Out:
#                                      frequency  percentage  cumulative_perc
# 251_technology_investment_customers
# --                                          98    0.573099         0.573099
# Totalmente de acuerdo                       35    0.204678         0.777778
# De acuerdo                                  23    0.134503         0.912281
# Totalmente en desacuerdo                     7    0.040936         0.953216

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico columna 254_technology_roadmap
table1= freq_tbl(filtro['254_technology_roadmap'])
table1
# Out:
#            254_technology_roadmap  frequency  percentage  cumulative_perc
# 0                              --        100    0.584795         0.584795
# 1        Totalmente en desacuerdo         32    0.187135         0.771930
# 2           Totalmente de acuerdo         12    0.070175         0.842105
# 3                      De acuerdo         11    0.064327         0.906433
# 4  Ni de acuerdo ni en desacuerdo          9    0.052632         0.959064
# 5                   En desacuerdo          7    0.040936         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>10]
Filtro
# Out:
#      254_technology_roadmap  frequency  percentage  cumulative_perc
# 0                        --        100    0.584795         0.584795
# 1  Totalmente en desacuerdo         32    0.187135         0.771930
# 2     Totalmente de acuerdo         12    0.070175         0.842105
# 3                De acuerdo         11    0.064327         0.906433

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('254_technology_roadmap')
Filtro_index
# Out:
#                           frequency  percentage  cumulative_perc
# 254_technology_roadmap
# --                              100    0.584795         0.584795
# Totalmente en desacuerdo         32    0.187135         0.771930
# Totalmente de acuerdo            12    0.070175         0.842105
# De acuerdo                       11    0.064327         0.906433

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Convertir DataFrame a CSV
filtro.to_csv("FiltroFINALextracción.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("FiltroFINALextracción.csv")
