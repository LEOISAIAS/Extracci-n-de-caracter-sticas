# %% [markdown]
# <a href="https://colab.research.google.com/github/LEOISAIAS/Extracci-n-de-caracter-sticas/blob/main/Extracci%C3%B3n_de_Caracter%C3%ADsticasA01275327.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extracción de características**
#
#
# ## Leonardo Isaías Guevara Pioquinto
#
# ## A01275327

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
##Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
data= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
data.info()

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(data)

# %%
#Imprimo los primeros 5 registro del dataframe
data.head()

# %% [markdown]
# ## **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)

# %%
#Encontramos Ouliers del Dataframe
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data2= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data2

# %% [markdown]
# # **PROCEDIMIENTO PARA EXTRAER VARIABLES CATEGORICAS DEL DATAFRAME**

# %%
# FILTRO COLUMNAS
Coldeseadas=data.iloc[ : , [3,9,15,27,36,37,38,49,50,55,56,57,60,62,65,67,70,72,75,76]]  #Columnas no consecutivas 
Coldeseadas
# Estoy filtrando las columnas más relevantes según mi criterio

# %%
#Corroboramos valores nulos
valores_nulos=Coldeseadas.isnull().sum()
valores_nulos

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
Coldeseadas['18_sales_records'] = Coldeseadas['18_sales_records'].fillna('--')
Coldeseadas['189_payment_methods'] = Coldeseadas['189_payment_methods'].fillna('--')
Coldeseadas['28_prefered_payment_method'] = Coldeseadas['28_prefered_payment_method'].fillna('--')
Coldeseadas['31_different_prices_payment_method'] = Coldeseadas['31_different_prices_payment_method'].fillna('--')
Coldeseadas['276_expected_days_informal_credit'] = Coldeseadas['276_expected_days_informal_credit'].fillna('--')
Coldeseadas['35_interest_rate'] = Coldeseadas['35_interest_rate'].fillna('--')
Coldeseadas['60_services'] = Coldeseadas['60_services'].fillna('--')
Coldeseadas['315_frequency_topups'] = Coldeseadas['315_frequency_topups'].fillna('--')
Coldeseadas['316_frequency_utility_bills'] = Coldeseadas['316_frequency_utility_bills'].fillna('--')
Coldeseadas['78_number_home_deliveries_week'] = Coldeseadas['78_number_home_deliveries_week'].fillna('--')
Coldeseadas['79_delivery_vehicle'] = Coldeseadas['79_delivery_vehicle'].fillna('--')
Coldeseadas['69_why_not_services'] = Coldeseadas['69_why_not_services'].fillna('--')
Coldeseadas['312_payment_of_utilities'] = Coldeseadas['312_payment_of_utilities'].fillna('--')
Coldeseadas['42_willingness_share_inventory_data_suppliers'] = Coldeseadas['42_willingness_share_inventory_data_suppliers'].fillna('--')
Coldeseadas['45_willingness_reorder_suppliers'] = Coldeseadas['45_willingness_reorder_suppliers'].fillna('--')
Coldeseadas['43_willingness_share_sales_data_suppliers'] = Coldeseadas['43_willingness_share_sales_data_suppliers'].fillna('--')
Coldeseadas['58_willingness_share_sales_data_mse'] = Coldeseadas['58_willingness_share_sales_data_mse'].fillna('--')
Coldeseadas

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=Coldeseadas.isnull().sum()
valores_nulos

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Coldeseadas['18_sales_records'])
table1
# Out:
#                                      18_sales_records  frequency  percentage  \
# 0                                                  --         61    0.356725
# 1                                            En papel         47    0.274854
# 2                Software especializado + computadora         22    0.128655
# 3                                          No lo hago         14    0.081871
# 4                                            En Excel         10    0.058480
# 5                         Caja registradora (análoga)          4    0.023392
# 6                                   En Excel,En papel          4    0.023392
# 7            Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 8   Aplicación móvil (i.e. App) + smartphone,Caja ...          1    0.005848
# 9                                           Contadora          1    0.005848
# 10                                             Notas           1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#                        18_sales_records  frequency  percentage  \
# 0                                    --         61    0.356725
# 1                              En papel         47    0.274854
# 2  Software especializado + computadora         22    0.128655
# 3                            No lo hago         14    0.081871
# 4                              En Excel         10    0.058480
# 5           Caja registradora (análoga)          4    0.023392
# 6                     En Excel,En papel          4    0.023392
#
#    cumulative_perc
# 0         0.356725
# 1         0.631579
# 2         0.760234
# 3         0.842105
# 4         0.900585
# 5         0.923977
# 6         0.947368

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('18_sales_records')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 18_sales_records
# --                                           61    0.356725         0.356725
# En papel                                     47    0.274854         0.631579
# Software especializado + computadora         22    0.128655         0.760234
# No lo hago                                   14    0.081871         0.842105
# En Excel                                     10    0.058480         0.900585
# Caja registradora (análoga)                   4    0.023392         0.923977
# En Excel,En papel                             4    0.023392         0.947368

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Modo de venta')
plt.xlabel('Tipo de registro')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(data['189_payment_methods'])
table2
# Out:
#                                  189_payment_methods  frequency  percentage  \
# 0                                           Efectivo         40    0.233918
# 1  Efectivo,Tarjeta de débito y/o crédito,Transfe...         30    0.175439
# 2             Efectivo,Tarjeta de débito y/o crédito         19    0.111111
# 3               Efectivo,Transferencia interbancaria         15    0.087719
# 4  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          1    0.005848
# 5  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          1    0.005848
# 6                      Tarjeta de débito y/o crédito          1    0.005848
#
#    cumulative_perc
# 0         0.373832
# 1         0.654206
# 2         0.831776
# 3         0.971963
# 4         0.981308
# 5         0.990654
# 6         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table2[table2['frequency']>1]
Filtro2
# Out:
#                                  189_payment_methods  frequency  percentage  \
# 0                                           Efectivo         40    0.233918
# 1  Efectivo,Tarjeta de débito y/o crédito,Transfe...         30    0.175439
# 2             Efectivo,Tarjeta de débito y/o crédito         19    0.111111
# 3               Efectivo,Transferencia interbancaria         15    0.087719
#
#    cumulative_perc
# 0         0.373832
# 1         0.654206
# 2         0.831776
# 3         0.971963

# %%
#Ajusto el indice de mi dataframe
Filtro_index2= Filtro2.set_index('189_payment_methods')
Filtro_index2
# Out:
#                                                     frequency  percentage  \
# 189_payment_methods
# Efectivo                                                   40    0.233918
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         30    0.175439
# Efectivo,Tarjeta de débito y/o crédito                     19    0.111111
# Efectivo,Transferencia interbancaria                       15    0.087719
#
#                                                     cumulative_perc
# 189_payment_methods
# Efectivo                                                   0.373832
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         0.654206
# Efectivo,Tarjeta de débito y/o crédito                     0.831776
# Efectivo,Transferencia interbancaria                       0.971963

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Método de pago')
plt.xlabel('Tipo de método')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(data['60_services'])
table3
# Out:
#                                           60_services  frequency  percentage  \
# 0                                             Ninguno         44    0.257310
# 1                                 Entrega a domicilio         15    0.087719
# 2                                  Recarga telefónica          7    0.040936
# 3   Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 4              Entrega a domicilio,Recarga telefónica          2    0.011696
# 5                                Toma de papa nicolau          1    0.005848
# 6                                      Renta de local          1    0.005848
# 7                                               venta          1    0.005848
# 8   Entrega a domicilio,Recarga telefónica,Recepci...          1    0.005848
# 9   Entrega a domicilio,Pago de servicios públicos...          1    0.005848
# 10  Pago de servicios públicos (e.g. Yastas),Recar...          1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro3= table3[table3['frequency']>1]
Filtro3
# Out:
#                                          60_services  frequency  percentage  \
# 0                                            Ninguno         44    0.257310
# 1                                Entrega a domicilio         15    0.087719
# 2                                 Recarga telefónica          7    0.040936
# 3  Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 4             Entrega a domicilio,Recarga telefónica          2    0.011696
#
#    cumulative_perc
# 0         0.571429
# 1         0.766234
# 2         0.857143
# 3         0.883117
# 4         0.909091

# %%
#Ajusto el indice de mi dataframe
#Filtro_index3= Filtro.set_index('60_services')
#Filtro_index3

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(data['79_delivery_vehicle'])
table4
# Out:
#                79_delivery_vehicle  frequency  percentage  cumulative_perc
# 0  El cliente los recoge en tienda          1    0.005848              0.5
# 1                        Automóvil          1    0.005848              1.0

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('79_delivery_vehicle')
Filtro_index

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro4= table4[table4['frequency']>1]
Filtro4
# Out:
# Empty DataFrame
# Columns: [79_delivery_vehicle, frequency, percentage, cumulative_perc]
# Index: []
